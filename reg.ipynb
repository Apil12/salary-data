# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df=pd.read_csv('Salary Data.csv',usecols=['Age','Gender','Education Level','Years of Experience','Salary'])
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [375 rows x 5 columns]

# %%
df.shape
# Out:
# (375, 5)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Years of Experience', 'Salary'], dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 370     True
# 371    False
# 372     True
# 373     True
# 374     True
# Length: 375, dtype: bool

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
df.duplicated(subset=['Age'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 370     True
# 371     True
# 372     True
# 373     True
# 374     True
# Length: 373, dtype: bool

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %% [markdown]
# # Plotting pie chart for different age group which exists in this dataset..

# %%
Age_count=pd.DataFrame(df['Age'].value_counts())
Age_count
Age_count.index.values
Age_count.plot(kind="bar",subplots=True,figsize=(20, 15))
# Out:
# array([<Axes: title={'center': 'count'}, xlabel='Age'>], dtype=object)

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %% [markdown]
# # Plotting bar graph to know  in average which gender earns how much salary

# %%
get_gender=df.groupby('Gender').Salary.mean().plot(kind="bar",legend=True,color=["r","c"])
plt.xlabel("Category called Gender")
plt.ylabel("Average salary")
plt.xticks(rotation=360)
# Out:
# (array([0, 1]), [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %% [markdown]
# # Plotting bar graph to know in average which Degree people earns how much salary

# %%
get_edlvl=df.groupby('Education Level').Salary.mean().plot(legend=True,kind="bar",color=["c","y","b"])
plt.xlabel("Category called Education level")
plt.ylabel("Average salary..")
plt.xticks(rotation=360)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, "Bachelor's"), Text(1, 0, "Master's"), Text(2, 0, 'PhD')])

# %%
get_edlvl=df.groupby('Education Level').Salary.mean().plot(legend=True,kind="bar",color=["c","y","b"])
df.groupby('Gender').Salary.mean().plot(kind="bar",legend=True,color=["r","c"])
plt.xlabel("Category called Education level")
plt.ylabel("Average salary..")
plt.xticks(rotation=360)
# Out:
# (array([0, 1]), [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
mean_salary_by_edu = df.groupby('Education Level')['Salary'].mean()
mean_salary_by_edu.plot(kind='bar', legend=True, color=["c", "y", "b"])
plt.xlabel("Education Level")
plt.ylabel("Average Salary")
plt.title("Average Salary by Education Level")
plt.xticks(rotation=360)
plt.show()

# Plotting bar graph for average salary by gender
mean_salary_by_gender = df.groupby('Gender')['Salary'].mean()
mean_salary_by_gender.plot(kind='bar', legend=True, color=["r", "c"])
plt.xlabel("Gender")
plt.ylabel("Average Salary")
plt.title("Average Salary by Gender")
plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# # Plotting bar graph to know in average which Years of experience group earns how much salary

# %%
df.groupby('Years of Experience').Salary.mean().plot.bar(legend=True,figsize=(20, 15))
# Out:
# <Axes: xlabel='Years of Experience'>

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
df.groupby('Gender').Salary.mean().plot.pie(labels=df['Gender'],autopct="%0.1f%%",subplots=True,colors=['c','y'])
plt.show()

# %% [markdown]
# # Plotting bar graph to analysis which Age groups earns how much salary

# %%
df.groupby('Age').Salary.mean().plot.bar(legend=True,figsize=(20, 15))
# Out:
# <Axes: xlabel='Age'>

# %%
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
df.groupby('Education Level').Age.value_counts()
# Out:
# Education Level  Age
# Bachelor's       29.0    21
#                  31.0    20
#                  33.0    19
#                  35.0    18
#                  36.0    18
#                          ..
# PhD              36.0     1
#                  48.0     1
#                  49.0     1
#                  51.0     1
#                  52.0     1
# Name: count, Length: 72, dtype: int64

# %%
df['Education Level'].value_counts() #bachelor,master ani phd padni kati jana xan..
# Out:
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64

# %%
new_df=df[['Age','Gender','Education Level','Years of Experience','Salary']]

# %%
new_df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(new_df)
plt.show()

# %%
sns.scatterplot(x=new_df['Years of Experience'],y=new_df['Salary'])
plt.show()

# %%
new_df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
new_df['Gender'].replace("Male",1,inplace=True)
new_df['Gender'].replace("Female", 0, inplace=True)

# %%
new_df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0       1      Bachelor's                  5.0   90000.0
# 1    28.0       0        Master's                  3.0   65000.0
# 2    45.0       1             PhD                 15.0  150000.0
# 3    36.0       0      Bachelor's                  7.0   60000.0
# 4    52.0       1        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0       0      Bachelor's                  8.0   85000.0
# 371  43.0       1        Master's                 19.0  170000.0
# 372  29.0       0      Bachelor's                  2.0   40000.0
# 373  34.0       1      Bachelor's                  7.0   90000.0
# 374  44.0       0             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
new_df['Education Level'].replace("Bachelor's", 0, inplace=True)
new_df['Education Level'].replace("Master's", 1, inplace=True)
new_df['Education Level'].replace("PhD", 2, inplace=True)

# %%
new_df
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 0    32.0       1                0                  5.0   90000.0
# 1    28.0       0                1                  3.0   65000.0
# 2    45.0       1                2                 15.0  150000.0
# 3    36.0       0                0                  7.0   60000.0
# 4    52.0       1                1                 20.0  200000.0
# ..    ...     ...              ...                  ...       ...
# 370  35.0       0                0                  8.0   85000.0
# 371  43.0       1                1                 19.0  170000.0
# 372  29.0       0                0                  2.0   40000.0
# 373  34.0       1                0                  7.0   90000.0
# 374  44.0       0                2                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_data,test_data=train_test_split(new_df,train_size=0.7,test_size=0.3,random_state=1)
train_data
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 146  42.0       0                2                 16.0  150000.0
# 222  33.0       1                0                  7.0  100000.0
# 119  35.0       1                1                 10.0  120000.0
# 80   36.0       1                0                  8.0   70000.0
# 88   46.0       1                1                 21.0  135000.0
# ..    ...     ...              ...                  ...       ...
# 204  36.0       1                0                  7.0   90000.0
# 256  34.0       0                1                  6.0  100000.0
# 72   45.0       1                2                 16.0  190000.0
# 236  37.0       0                0                  9.0  100000.0
# 37   42.0       1                1                 14.0  115000.0
#
# [261 rows x 5 columns]

# %%
train_data
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 146  42.0       0                2                 16.0  150000.0
# 222  33.0       1                0                  7.0  100000.0
# 119  35.0       1                1                 10.0  120000.0
# 80   36.0       1                0                  8.0   70000.0
# 88   46.0       1                1                 21.0  135000.0
# ..    ...     ...              ...                  ...       ...
# 204  36.0       1                0                  7.0   90000.0
# 256  34.0       0                1                  6.0  100000.0
# 72   45.0       1                2                 16.0  190000.0
# 236  37.0       0                0                  9.0  100000.0
# 37   42.0       1                1                 14.0  115000.0
#
# [261 rows x 5 columns]

# %%
test_data
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 67   31.0       0                0                  5.0   45000.0
# 348  28.0       0                0                  1.0   35000.0
# 343  41.0       1                0                 14.0  150000.0
# 295  33.0       1                0                  4.0   60000.0
# 90   36.0       1                2                 11.0  120000.0
# ..    ...     ...              ...                  ...       ...
# 247  31.0       1                0                  3.0   50000.0
# 162  30.0       0                0                  3.0   45000.0
# 209  30.0       0                0                  2.0   40000.0
# 122  33.0       0                0                  5.0   50000.0
# 336  29.0       0                0                  2.0   40000.0
#
# [112 rows x 5 columns]

# %%
new_df
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 0    32.0       1                0                  5.0   90000.0
# 1    28.0       0                1                  3.0   65000.0
# 2    45.0       1                2                 15.0  150000.0
# 3    36.0       0                0                  7.0   60000.0
# 4    52.0       1                1                 20.0  200000.0
# ..    ...     ...              ...                  ...       ...
# 370  35.0       0                0                  8.0   85000.0
# 371  43.0       1                1                 19.0  170000.0
# 372  29.0       0                0                  2.0   40000.0
# 373  34.0       1                0                  7.0   90000.0
# 374  44.0       0                2                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
train_data.describe()
# Out:
#               Age      Gender  Education Level  Years of Experience  \
# count  261.000000  261.000000       261.000000           261.000000
# mean    37.222222    0.540230         0.509579             9.883142
# std      6.912951    0.499336         0.699522             6.441209
# min     23.000000    0.000000         0.000000             0.000000
# 25%     32.000000    0.000000         0.000000             4.000000
# 50%     36.000000    1.000000         0.000000             9.000000
# 75%     43.000000    1.000000         1.000000            15.000000
# max     53.000000    1.000000         2.000000            25.000000
#
#               Salary
# count     261.000000
# mean   100633.524904
# std     47531.381098
# min       350.000000
# 25%     60000.000000
# 50%     95000.000000
# 75%    130000.000000
# max    250000.000000

# %%
train_data.head()
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 146  42.0       0                2                 16.0  150000.0
# 222  33.0       1                0                  7.0  100000.0
# 119  35.0       1                1                 10.0  120000.0
# 80   36.0       1                0                  8.0   70000.0
# 88   46.0       1                1                 21.0  135000.0

# %%
train_data
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 146  42.0       0                2                 16.0  150000.0
# 222  33.0       1                0                  7.0  100000.0
# 119  35.0       1                1                 10.0  120000.0
# 80   36.0       1                0                  8.0   70000.0
# 88   46.0       1                1                 21.0  135000.0
# ..    ...     ...              ...                  ...       ...
# 204  36.0       1                0                  7.0   90000.0
# 256  34.0       0                1                  6.0  100000.0
# 72   45.0       1                2                 16.0  190000.0
# 236  37.0       0                0                  9.0  100000.0
# 37   42.0       1                1                 14.0  115000.0
#
# [261 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
vare=['Age','Years of Experience','Salary']
train_data[vare] = scaler.fit_transform(train_data[vare])
train_data[vare]
# Out:
#           Age  Years of Experience    Salary
# 146  0.633333                 0.64  0.599439
# 222  0.333333                 0.28  0.399159
# 119  0.400000                 0.40  0.479271
# 80   0.433333                 0.32  0.278991
# 88   0.766667                 0.84  0.539355
# ..        ...                  ...       ...
# 204  0.433333                 0.28  0.359103
# 256  0.366667                 0.24  0.399159
# 72   0.733333                 0.64  0.759664
# 236  0.466667                 0.36  0.399159
# 37   0.633333                 0.56  0.459243
#
# [261 rows x 3 columns]

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(new_df.corr(), annot = True,)
plt.show()

# %%
y_train = train_data.pop('Salary')
X_train = train_data
(X_train)
# Out:
#           Age  Gender  Education Level  Years of Experience
# 146  0.633333       0                2                 0.64
# 222  0.333333       1                0                 0.28
# 119  0.400000       1                1                 0.40
# 80   0.433333       1                0                 0.32
# 88   0.766667       1                1                 0.84
# ..        ...     ...              ...                  ...
# 204  0.433333       1                0                 0.28
# 256  0.366667       0                1                 0.24
# 72   0.733333       1                2                 0.64
# 236  0.466667       0                0                 0.36
# 37   0.633333       1                1                 0.56
#
# [261 rows x 4 columns]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)

#rfe = RFE(lm, 10)
rfe = RFE(lm, n_features_to_select=12)
#running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Age', True, 1),
#  ('Gender', True, 1),
#  ('Education Level', True, 1),
#  ('Years of Experience', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Years of Experience'], dtype='object')

# %%
X_train_rfe = X_train[col]
X_train_rfe
# Out:
#           Age  Gender  Education Level  Years of Experience
# 146  0.633333       0                2                 0.64
# 222  0.333333       1                0                 0.28
# 119  0.400000       1                1                 0.40
# 80   0.433333       1                0                 0.32
# 88   0.766667       1                1                 0.84
# ..        ...     ...              ...                  ...
# 204  0.433333       1                0                 0.28
# 256  0.366667       0                1                 0.24
# 72   0.733333       1                2                 0.64
# 236  0.466667       0                0                 0.36
# 37   0.633333       1                1                 0.56
#
# [261 rows x 4 columns]

# %%
import statsmodels.api as sm
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
X_train_rfe
# Out:
#      const       Age  Gender  Education Level  Years of Experience
# 146    1.0  0.633333       0                2                 0.64
# 222    1.0  0.333333       1                0                 0.28
# 119    1.0  0.400000       1                1                 0.40
# 80     1.0  0.433333       1                0                 0.32
# 88     1.0  0.766667       1                1                 0.84
# ..     ...       ...     ...              ...                  ...
# 204    1.0  0.433333       1                0                 0.28
# 256    1.0  0.366667       0                1                 0.24
# 72     1.0  0.733333       1                2                 0.64
# 236    1.0  0.466667       0                0                 0.36
# 37     1.0  0.633333       1                1                 0.56
#
# [261 rows x 5 columns]

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()   # Running the linear model

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.882
# Method:                 Least Squares   F-statistic:                     488.1
# Date:                Fri, 14 Jul 2023   Prob (F-statistic):          1.87e-118
# Time:                        16:06:57   Log-Likelihood:                 344.28
# No. Observations:                 261   AIC:                            -678.6
# Df Residuals:                     256   BIC:                            -660.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0802      0.015      5.499      0.000       0.051       0.109
# ...

# %%
X_train_new1 = X_train_rfe.drop(["Age"], axis = 1)
X_train_new1
# Out:
#      const  Gender  Education Level  Years of Experience
# 146    1.0       0                2                 0.64
# 222    1.0       1                0                 0.28
# 119    1.0       1                1                 0.40
# 80     1.0       1                0                 0.32
# 88     1.0       1                1                 0.84
# ..     ...     ...              ...                  ...
# 204    1.0       1                0                 0.28
# 256    1.0       0                1                 0.24
# 72     1.0       1                2                 0.64
# 236    1.0       0                0                 0.36
# 37     1.0       1                1                 0.56
#
# [261 rows x 4 columns]

# %%
lm = sm.OLS(y_train,X_train_new1).fit()   # Running the linear model

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     619.5
# Date:                Fri, 14 Jul 2023   Prob (F-statistic):          2.76e-117
# Time:                        16:06:57   Log-Likelihood:                 338.16
# No. Observations:                 261   AIC:                            -668.3
# Df Residuals:                     257   BIC:                            -654.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1210      0.009     13.502      0.000       0.103       0.139
# ...

# %%
y_train_price = lm.predict(X_train_new1)
y_train_price
# Out:
# 146    0.610227
# 222    0.319470
# 119    0.443518
# 80     0.343586
# 88     0.708783
#          ...
# 204    0.319470
# 256    0.317375
# 72     0.639910
# 236    0.338017
# 37     0.539978
# Length: 261, dtype: float64

# %%
test_data
# lm.predict(test_data)
# Out:
#       Age  Gender  Education Level  Years of Experience    Salary
# 67   31.0       0                0                  5.0   45000.0
# 348  28.0       0                0                  1.0   35000.0
# 343  41.0       1                0                 14.0  150000.0
# 295  33.0       1                0                  4.0   60000.0
# 90   36.0       1                2                 11.0  120000.0
# ..    ...     ...              ...                  ...       ...
# 247  31.0       1                0                  3.0   50000.0
# 162  30.0       0                0                  3.0   45000.0
# 209  30.0       0                0                  2.0   40000.0
# 122  33.0       0                0                  5.0   50000.0
# 336  29.0       0                0                  2.0   40000.0
#
# [112 rows x 5 columns]

# %%
var=['Age','Years of Experience','Salary']
test_data[var] = scaler.fit_transform(test_data[var])
test_data[var]
# Out:
#           Age  Years of Experience    Salary
# 67   0.250000                 0.20  0.088235
# 348  0.142857                 0.04  0.029412
# 343  0.607143                 0.56  0.705882
# 295  0.321429                 0.16  0.176471
# 90   0.428571                 0.44  0.529412
# ..        ...                  ...       ...
# 247  0.250000                 0.12  0.117647
# 162  0.214286                 0.12  0.088235
# 209  0.214286                 0.08  0.058824
# 122  0.321429                 0.20  0.117647
# 336  0.178571                 0.08  0.058824
#
# [112 rows x 3 columns]

# %%
test_data[var].describe()
# Out:
#               Age  Years of Experience      Salary
# count  112.000000           112.000000  112.000000
# mean     0.497130             0.415000    0.414391
# std      0.265325             0.273456    0.294529
# min      0.000000             0.000000    0.000000
# 25%      0.250000             0.120000    0.117647
# 50%      0.535714             0.440000    0.397059
# 75%      0.714286             0.640000    0.705882
# max      1.000000             1.000000    1.000000

# %%
y_test = test_data.pop('Salary')
X_test = test_data

# %%
y_test
# Out:
# 67     0.088235
# 348    0.029412
# 343    0.705882
# 295    0.176471
# 90     0.529412
#          ...
# 247    0.117647
# 162    0.088235
# 209    0.058824
# 122    0.117647
# 336    0.058824
# Name: Salary, Length: 112, dtype: float64

# %%
X_test
# Out:
#           Age  Gender  Education Level  Years of Experience
# 67   0.250000       0                0                 0.20
# 348  0.142857       0                0                 0.04
# 343  0.607143       1                0                 0.56
# 295  0.321429       1                0                 0.16
# 90   0.428571       1                2                 0.44
# ..        ...     ...              ...                  ...
# 247  0.250000       1                0                 0.12
# 162  0.214286       0                0                 0.12
# 209  0.214286       0                0                 0.08
# 122  0.321429       0                0                 0.20
# 336  0.178571       0                0                 0.08
#
# [112 rows x 4 columns]

# %%
# X_test.drop('Age',axis=1,inplace=True)
# X_test.drop('Education Level',axis=1,inplace=True)
X_test
# Out:
#           Age  Gender  Education Level  Years of Experience
# 67   0.250000       0                0                 0.20
# 348  0.142857       0                0                 0.04
# 343  0.607143       1                0                 0.56
# 295  0.321429       1                0                 0.16
# 90   0.428571       1                2                 0.44
# ..        ...     ...              ...                  ...
# 247  0.250000       1                0                 0.12
# 162  0.214286       0                0                 0.12
# 209  0.214286       0                0                 0.08
# 122  0.321429       0                0                 0.20
# 336  0.178571       0                0                 0.08
#
# [112 rows x 4 columns]

# %%
X_test_new = X_test[['Gender', 'Education Level','Years of Experience']]
# Adding a constant variable
X_test_new = sm.add_constant(X_test_new)
X_test_new
# Out:
#      const  Gender  Education Level  Years of Experience
# 67     1.0       0                0                 0.20
# 348    1.0       0                0                 0.04
# 343    1.0       1                0                 0.56
# 295    1.0       1                0                 0.16
# 90     1.0       1                2                 0.44
# ..     ...     ...              ...                  ...
# 247    1.0       1                0                 0.12
# 162    1.0       0                0                 0.12
# 209    1.0       0                0                 0.08
# 122    1.0       0                0                 0.20
# 336    1.0       0                0                 0.08
#
# [112 rows x 4 columns]

# %%
y_pred = lm.predict(X_test_new)
y_pred
# Out:
# 67     0.241557
# 348    0.145097
# 343    0.488276
# 295    0.247125
# 90     0.519335
#          ...
# 247    0.223010
# 162    0.193327
# 209    0.169212
# 122    0.241557
# 336    0.169212
# Length: 112, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8375102155200435

# %%
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# # steps for linear regression

# %%
# At first, file is readed and dataset is converted into dataframe.
# null values are removed from dataset EDA has been performed to analysis of data.
# Dimension reduction has been done to convert categorical into numerical data..
# dataset is converted into machine learning train and test data.
# minmax scalar algorithm has been implemented to normalaize the dataset (to convert high value of data into lower ones..)
# heatmap has been plotted for dataframe to see co-relation  matrix it shows that which values are same means
# columns are highly corelated and which values need to be removed..
# Although we can removed those manually but we use new technique called RFE to removed those unwanted columns.
# After that ols technique is used to find coeffiecent for the equations it shows summary of the whole dataset too..
# after that we need to test the model and find out y pred also using r2 score method accuracy of model is calculated..

# %%
import numpy as np
import matplotlib.pyplot as plt

# Scatter plot of y_test vs y_pred
plt.scatter(y_test, y_pred)
plt.title('y_test vs y_pred', fontsize=20)
plt.xlabel('y_test', fontsize=18)
plt.ylabel('y_pred', fontsize=16)

# Plotting the best-fit line
x = np.linspace(min(y_test), max(y_test), 100)
y = x  # Assuming a simple best-fit line with slope=1 and intercept=0
plt.plot(x, y, color='red')

plt.show()
